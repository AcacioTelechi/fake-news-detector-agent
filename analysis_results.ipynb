# %%
import json
import pandas as pd

# %%
df = pd.read_json('./output/analysis_results_20260131_143131.jsonl', lines=True)

# %%
df
# Out:
#                            id_mention  \
# 0    0001c9de9cf636d2b5faa31eb88a87cd
# 1    00018e4f326728431c1c97b775f31b67
# 2    00006b826eb2064cd4c069df5e9bebac
# 3    00014e37ef658664f02ab02c991d45f7
# 4    0001df78f4f1323c23cab956a749ac62
# ..                                ...
# 923  011bb63099bf5f347639915ba58932c8
# 924  011be313053dbaa73326730b9cf69d95
# 925  011c41ebb17c5d98e3ff2c9b3d0e4676
# 926  011bdc525679de9fa8b758782db4e921
# 927  011c0f3424f1731b1f0f3a8f8876555b
#
#                                              full_text  success  \
# 0    Um carro da funerária acaba de entrar no hospi...     True
# 1    Qual é sua opinião sobre isso? 👀🤔 . Já que o D...     True
# 2    Gente pelo amor de Deus Boulos não , misericór...     True
# 3                                Estou com Boulos 50 🙏     True
# 4    Estadão Conteúdoi Estadão Conteúdo https://ist...     True
# ..                                                 ...      ...
# ...
